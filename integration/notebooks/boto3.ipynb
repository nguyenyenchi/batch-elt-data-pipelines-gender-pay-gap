# %% [markdown]
# ## Preprocess excel to csv files then upload to S3 bucket

# %%
# important: boto3 assumes that you have already authenticated to aws using `aws configure`
import boto3

# list all buckets in s3
# s3 = boto3.resource("s3")

# for bucket in s3.buckets.all():
#     print(bucket.name)

# # list objects in s3 
# bucket = s3.Bucket("eeh-files")
# for object in bucket.objects.all(): 
#     print(object)

s3 = boto3.client("s3")

s3.upload_file(
    Filename="../data/S3/EEH_2025_s3_test.csv",
    Bucket="eeh-files",
    Key='eeh/EEH_2025_s3_test.csv'
)
